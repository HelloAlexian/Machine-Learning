# %% [markdown]
# <a href="https://colab.research.google.com/github/helloalexian/Machine-Learning/blob/master/Copy_of_Skip_Gram_word2vec.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](https://github.com/udacity/deep-learning/blob/master/embeddings/assets/one_hot_encoding.png?raw=1)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](https://github.com/udacity/deep-learning/blob/master/embeddings/assets/lookup_matrix.png?raw=1)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='https://github.com/udacity/deep-learning/blob/master/embeddings/assets/tokenize_lookup.png?raw=1' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="https://github.com/udacity/deep-learning/blob/master/embeddings/assets/word2vec_architectures.png?raw=1" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import re
from collections import Counter

def preprocess(text):

    # Replace punctuation with tokens so we can use them in our model
    text = text.lower()
    text = text.replace('.', ' <PERIOD> ')
    text = text.replace(',', ' <COMMA> ')
    text = text.replace('"', ' <QUOTATION_MARK> ')
    text = text.replace(';', ' <SEMICOLON> ')
    text = text.replace('!', ' <EXCLAMATION_MARK> ')
    text = text.replace('?', ' <QUESTION_MARK> ')
    text = text.replace('(', ' <LEFT_PAREN> ')
    text = text.replace(')', ' <RIGHT_PAREN> ')
    text = text.replace('--', ' <HYPHENS> ')
    text = text.replace('?', ' <QUESTION_MARK> ')
    # text = text.replace('\n', ' <NEW_LINE> ')
    text = text.replace(':', ' <COLON> ')
    words = text.split()
    
    # Remove all words with  5 or fewer occurences
    word_counts = Counter(words)
    trimmed_words = [word for word in words if word_counts[word] > 5]

    return trimmed_words

def get_batches(int_text, batch_size, seq_length):
    """
    Return batches of input and target
    :param int_text: Text with the words replaced by their ids
    :param batch_size: The size of batch
    :param seq_length: The length of sequence
    :return: A list where each item is a tuple of (batch of input, batch of target).
    """
    n_batches = int(len(int_text) / (batch_size * seq_length))

    # Drop the last few characters to make only full batches
    xdata = np.array(int_text[: n_batches * batch_size * seq_length])
    ydata = np.array(int_text[1: n_batches * batch_size * seq_length + 1])

    x_batches = np.split(xdata.reshape(batch_size, -1), n_batches, 1)
    y_batches = np.split(ydata.reshape(batch_size, -1), n_batches, 1)

    return list(zip(x_batches, y_batches))


def create_lookup_tables(words):
    """
    Create lookup tables for vocabulary
    :param words: Input list of words
    :return: A tuple of dicts.  The first dict....
    """
    word_counts = Counter(words)
    sorted_vocab = sorted(word_counts, key=word_counts.get, reverse=True)
    int_to_vocab = {ii: word for ii, word in enumerate(sorted_vocab)}
    vocab_to_int = {word: ii for ii, word in int_to_vocab.items()}
    
    return vocab_to_int, int_to_vocab

# %%
import time

import numpy as np
import tensorflow as tf

# import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()
# Out:
# Text8 Dataset: 31.4MB [01:32, 337kB/s]

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %%
int_words[:10]
# Out:
# [5233, 3080, 11, 5, 194, 1, 3133, 45, 58, 155]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
import random
## Your code here
threhold = 1e-5
word_counts = Counter(int_words)
total_count = len(int_words)
freqs = {word: count/total_count for word, count in word_counts.items()}
p_drop = {word: 1 - np.sqrt(threhold / freqs[word]) for word in word_counts}
train_words = [word for word in int_words if random.random() < (1 - p_drop[word])]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    r = random.randint(1, window_size + 1)
    start = idx - r if (idx - r) > 0 else 0 
    end = idx + r
    target_words = set(words[start:idx] + words[idx+1:end+1])
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](https://github.com/udacity/deep-learning/blob/master/embeddings/assets/skip_gram_net_arch.png?raw=1)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1)) # create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding, inputs) # use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))# create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros(n_vocab))# create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, embed, n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0617 13:17:08.485487 140685572474752 deprecation.py:506] From <ipython-input-17-2aa168c49a56>:13: calling reduce_sum_v1 (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6627 0.0410 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6268 0.0321 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.5091 0.0320 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5912 0.0318 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5275 0.0318 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5262 0.0319 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5426 0.0318 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5522 0.0318 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4702 0.0319 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4078 0.0318 sec/batch
# Nearest to will: disapproving, susceptibility, encircles, victorious, marchand, exposed, kanons, ixians,
# Nearest to two: radios, mm, mug, spoil, unsigned, station, northland, girlfriends,
# Nearest to that: connector, hierarchy, anaheim, dismemberment, headstone, damages, lumbering, telford,
# Nearest to known: rhenish, flippers, blasting, esq, assyria, barracks, alshehhi, crux,
# Nearest to used: b, complexity, reappear, smegma, acceded, lublin, cleaning, slaughter,
# Nearest to are: outdated, fatherland, ornella, belfast, metal, swordsman, turning, endothermic,
# Nearest to if: geste, whence, disinterest, rivaling, viridis, isambard, determinant, prelates,
# Nearest to i: hinted, complutense, bootlegs, inversion, radionuclides, biochemists, everest, officiel,
# Nearest to assembly: uttar, settlers, randomized, gorbachev, hring, ascents, indentured, telencephalon,
# Nearest to accepted: eifel, saffron, slavoj, kilgore, instrumentals, westernization, viewership, kalarippayattu,
# Nearest to notes: repay, santander, brittle, chuck, full, specialisation, medieval, overgrowth,
# Nearest to bbc: ranks, listen, lastnode, vigorously, troughs, appeasement, heraclea, ridings,
# Nearest to hold: carrying, frederik, volleys, eller, ossification, plucking, anti, selby,
# Nearest to frac: faraway, mallow, shotcrete, bacall, epithet, emperor, piped, alltel,
# Nearest to pope: rieure, precipitate, tenacious, harar, freleng, mako, tray, israel,
# Nearest to ocean: telescopes, redux, palaestina, styled, second, catalyzed, cape, farthest,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4858 0.0330 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3730 0.0320 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3564 0.0318 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2346 0.0318 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1435 0.0319 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1225 0.0319 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.0720 0.0318 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0385 0.0318 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0194 0.0318 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9561 0.0318 sec/batch
# Nearest to will: exposed, through, amount, victorious, encircles, susceptibility, disapproving, vic,
# Nearest to two: radios, mm, station, dictionaries, whilst, coat, mug, unsigned,
# Nearest to that: hierarchy, connector, word, damages, anaheim, reported, counterpart, top,
# Nearest to known: materials, rhenish, council, duties, flippers, blasting, pupil, alert,
# Nearest to used: b, complexity, could, evangelical, reappear, sichuan, level, arose,
# Nearest to are: times, metal, us, turning, outdated, fatherland, side, revolution,
# Nearest to if: geste, whence, rivaling, practical, separated, disinterest, determinant, serial,
# Nearest to i: hinted, has, complutense, officiel, lava, usually, students, compilation,
# Nearest to assembly: settlers, gorbachev, indentured, randomized, uttar, rotterdam, hring, eugen,
# Nearest to accepted: purely, instrumentals, eifel, load, rather, slavoj, finance, saffron,
# Nearest to notes: brittle, repay, full, medieval, chuck, act, santander, specialisation,
# Nearest to bbc: ranks, listen, atonement, vigorously, troughs, accounted, lastnode, evolution,
# Nearest to hold: carrying, frederik, anti, psychology, encouragement, plucking, volleys, eller,
# Nearest to frac: emperor, join, faraway, bacall, mallow, steady, epithet, requirement,
# Nearest to pope: precipitate, rieure, israel, tenacious, harar, powered, reaction, nordic,
# Nearest to ocean: openly, second, done, beliefs, cape, styled, gained, telescopes,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9002 0.0318 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9171 0.0303 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8886 0.0302 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8838 0.0303 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.7960 0.0301 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8197 0.0300 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.7865 0.0301 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.8199 0.0301 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7592 0.0303 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7888 0.0302 sec/batch
# Nearest to will: exposed, susceptibility, victorious, disapproving, encircles, through, amount, counterintelligence,
# Nearest to two: radios, mm, mug, whilst, station, coat, kate, logarithms,
# Nearest to that: hierarchy, connector, word, damages, counterpart, anaheim, instantaneous, charitable,
# Nearest to known: duties, rhenish, materials, blasting, flippers, mary, council, fundamentally,
# Nearest to used: b, complexity, reappear, could, evangelical, acceded, arose, sichuan,
# Nearest to are: outdated, fatherland, crucifixion, metal, culinary, endothermic, ornella, turning,
# Nearest to if: whence, geste, practical, rivaling, determinant, separated, dimer, disinterest,
# Nearest to i: hinted, inversion, has, officiel, raven, complutense, lava, lpg,
# Nearest to assembly: settlers, gorbachev, saharan, indentured, randomized, eugen, unsure, hring,
# Nearest to accepted: instrumentals, eifel, purely, slavoj, saffron, ourselves, fide, finance,
# Nearest to notes: repay, full, brittle, medieval, santander, chuck, specialisation, act,
# Nearest to bbc: ranks, listen, vigorously, accounted, atonement, troughs, announces, cellar,
# Nearest to hold: carrying, frederik, psychology, plucking, eller, anti, duties, encouragement,
# Nearest to frac: emperor, steady, join, epithet, notable, faraway, requirement, bacall,
# Nearest to pope: precipitate, rieure, israel, tenacious, harar, nordic, powered, emitted,
# Nearest to ocean: farthest, openly, cauchy, telescopes, cape, palaestina, catalyzed, taped,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7918 0.0313 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7639 0.0302 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.6971 0.0301 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7105 0.0301 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7480 0.0308 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.6757 0.0307 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.6986 0.0305 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.6908 0.0304 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.6656 0.0304 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6775 0.0304 sec/batch
# Nearest to will: susceptibility, exposed, victorious, through, encircles, disapproving, amount, marchand,
# Nearest to two: radios, mug, mm, kate, whilst, one, station, fern,
# Nearest to that: hierarchy, connector, answering, word, headstone, be, damages, instantaneous,
# Nearest to known: duties, rhenish, blasting, assyria, flippers, mary, council, materials,
# Nearest to used: reappear, complexity, could, sichuan, arose, evangelical, radars, advertisement,
# Nearest to are: crucifixion, fatherland, outdated, metal, subsistence, culinary, endothermic, ornella,
# Nearest to if: whence, geste, determinant, practical, rivaling, dimer, peugeot, benefitting,
# Nearest to i: hinted, inversion, officiel, everest, complutense, raven, triads, bono,
# Nearest to assembly: settlers, gorbachev, saharan, indentured, uttar, hring, cronin, executions,
# Nearest to accepted: instrumentals, kilgore, slavoj, eifel, saffron, westernization, ourselves, purely,
# Nearest to notes: repay, brittle, full, santander, medieval, specialisation, chuck, hartford,
# Nearest to bbc: ranks, listen, announces, galveston, vigorously, appeasement, troughs, accounted,
# Nearest to hold: carrying, frederik, plucking, anti, duties, volleys, eller, supplant,
# Nearest to frac: epithet, requirement, steady, prematurely, weight, join, sum, distract,
# Nearest to pope: precipitate, rieure, tenacious, israel, harar, cora, nordic, grandiose,
# Nearest to ocean: farthest, palaestina, cauchy, openly, cape, bottling, strasbourg, musketeers,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6974 0.0309 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6664 0.0300 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6514 0.0305 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6270 0.0309 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6365 0.0308 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6526 0.0310 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.6172 0.0224 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5566 0.0303 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5176 0.0304 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5115 0.0305 sec/batch
# Nearest to will: susceptibility, encircles, exposed, through, disapproving, marchand, amount, victorious,
# Nearest to two: radios, mug, one, mm, seven, station, three, kate,
# Nearest to that: hierarchy, connector, be, headstone, word, answering, damages, counterpart,
# Nearest to known: rhenish, blasting, duties, materials, empiricists, assyria, barracks, flippers,
# Nearest to used: could, radars, complexity, reappear, fiber, holds, infty, description,
# Nearest to are: subsistence, metal, endothermic, culinary, fatherland, outdated, crucifixion, ornella,
# Nearest to if: whence, determinant, geste, peugeot, dimer, practical, benefitting, rivaling,
# Nearest to i: hinted, inversion, complutense, officiel, everest, raven, triads, lpg,
# Nearest to assembly: gorbachev, settlers, saharan, indentured, uttar, perrin, cronin, bystander,
# Nearest to accepted: instrumentals, kilgore, eifel, saffron, slavoj, apportionment, westernization, thucydides,
# Nearest to notes: repay, brittle, medieval, santander, full, canonised, specialisation, hartford,
# Nearest to bbc: ranks, listen, announces, galveston, appeasement, troughs, lastnode, du,
# Nearest to hold: frederik, volleys, carrying, plucking, anti, phoneme, supplant, ossification,
# Nearest to frac: epithet, sum, steady, weight, requirement, distract, mallow, unload,
# Nearest to pope: precipitate, rieure, israel, protectorate, harar, cora, tenacious, augusta,
# Nearest to ocean: palaestina, farthest, cape, cauchy, musketeers, catalyzed, bottling, lachish,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4922 0.0312 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.4761 0.0301 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4570 0.0305 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5246 0.0305 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4813 0.0303 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4633 0.0304 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4767 0.0303 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.4046 0.0303 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4377 0.0302 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4044 0.0307 sec/batch
# Nearest to will: susceptibility, encircles, exposed, through, disapproving, marchand, counterintelligence, difficult,
# Nearest to two: radios, mm, three, station, mug, total, honeywell, zero,
# Nearest to that: hierarchy, be, connector, damages, answering, headstone, word, counterpart,
# Nearest to known: rhenish, blasting, duties, materials, limitless, empiricists, flippers, faint,
# Nearest to used: radars, could, reappear, description, complexity, fiber, infty, hamper,
# Nearest to are: subsistence, metal, endothermic, culinary, outdated, occur, depending, fatherland,
# Nearest to if: determinant, geste, whence, peugeot, notion, dimer, practical, change,
# Nearest to i: hinted, inversion, complutense, officiel, shoulders, everest, rebar, lpg,
# Nearest to assembly: gorbachev, saharan, settlers, legislative, indentured, perrin, cronin, afternoons,
# Nearest to accepted: kilgore, instrumentals, apportionment, ourselves, saffron, slavoj, thucydides, fide,
# Nearest to notes: repay, santander, medieval, brittle, full, funerary, specialisation, canonised,
# Nearest to bbc: ranks, galveston, announces, listen, moshoeshoe, lastnode, du, masterplan,
# Nearest to hold: volleys, carrying, ossification, phoneme, plucking, frederik, supplant, anti,
# Nearest to frac: sum, epithet, constant, mathbf, weight, vectors, steady, precision,
# Nearest to pope: israel, rieure, harar, augusta, precipitate, cora, tenacious, protectorate,
# Nearest to ocean: cape, southern, relay, flat, adjacent, farthest, heady, musketeers,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4473 0.0319 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4347 0.0302 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4335 0.0302 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.4130 0.0304 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4103 0.0302 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4465 0.0302 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3600 0.0309 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3919 0.0303 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4191 0.0302 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3955 0.0303 sec/batch
# Nearest to will: susceptibility, encircles, disapproving, marchand, exposed, through, anecdotes, counterintelligence,
# Nearest to two: three, radios, mm, station, one, zero, mug, five,
# Nearest to that: hierarchy, be, answering, connector, headstone, damages, ouster, instantaneous,
# Nearest to known: rhenish, blasting, empiricists, duties, limitless, materials, assyria, skopje,
# Nearest to used: radars, reappear, complexity, description, could, infty, essentially, fiber,
# Nearest to are: endothermic, outdated, culinary, subsistence, metal, precautions, occur, iir,
# Nearest to if: determinant, whence, geste, peugeot, dimer, notion, practical, topology,
# Nearest to i: hinted, shoulders, officiel, inversion, lpg, son, everest, stunted,
# Nearest to assembly: gorbachev, legislative, judicial, settlers, saharan, indentured, cronin, perrin,
# Nearest to accepted: kilgore, ourselves, apportionment, fide, hotspur, purely, austerlitz, instrumentals,
# Nearest to notes: medieval, santander, repay, brittle, full, redfield, canonised, specialisation,
# Nearest to bbc: ranks, galveston, moshoeshoe, announces, listen, lastnode, unconquered, du,
# Nearest to hold: volleys, phoneme, ossification, carrying, plucking, supplant, frederik, koyaanisqatsi,
# Nearest to frac: sum, mathbf, vectors, constant, cdot, epithet, weight, intersect,
# Nearest to pope: israel, rieure, harar, augusta, cora, precipitate, protectorate, tenacious,
# Nearest to ocean: relay, southern, cape, adjacent, pacific, flat, temperate, farthest,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3684 0.0313 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3947 0.0303 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3419 0.0303 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3438 0.0307 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3984 0.0302 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3709 0.0304 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.4187 0.0305 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3790 0.0303 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3566 0.0303 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3358 0.0303 sec/batch
# Nearest to will: susceptibility, disapproving, encircles, counterintelligence, marchand, difficult, pipe, anecdotes,
# Nearest to two: three, one, five, zero, radios, seven, four, mm,
# Nearest to that: hierarchy, be, answering, damages, civil, connector, instalments, alimentary,
# Nearest to known: blasting, empiricists, rhenish, materials, limitless, pronunciations, duties, trivium,
# Nearest to used: radars, reappear, could, complexity, description, essentially, infty, hamper,
# Nearest to are: subsistence, culinary, endothermic, outdated, occur, iir, precautions, nominative,
# Nearest to if: determinant, whence, peugeot, geste, dimer, notion, prelates, practical,
# Nearest to i: hinted, son, shoulders, officiel, complutense, inversion, lpg, everest,
# Nearest to assembly: gorbachev, legislative, indentured, criminal, judicial, settlers, perrin, maize,
# Nearest to accepted: kilgore, apportionment, fide, ourselves, depictions, thucydides, andrewes, undisclosed,
# Nearest to notes: medieval, santander, brittle, redfield, full, repay, isbns, specialisation,
# Nearest to bbc: ranks, galveston, moshoeshoe, listen, announces, lastnode, du, masterplan,
# Nearest to hold: ossification, plucking, volleys, carrying, phoneme, encouragement, koyaanisqatsi, supplant,
# Nearest to frac: sum, mathbf, cdot, vectors, constant, weight, intersect, steady,
# Nearest to pope: rieure, augusta, harar, israel, cora, tenacious, imperial, anastasia,
# Nearest to ocean: relay, southern, adjacent, cape, pacific, temperate, flat, intelsat,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3520 0.0315 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2789 0.0306 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3828 0.0304 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3811 0.0306 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3807 0.0301 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2745 0.0303 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3020 0.0302 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3704 0.0304 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2167 0.0302 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.3116 0.0303 sec/batch
# Nearest to will: susceptibility, disapproving, counterintelligence, encircles, anecdotes, difficult, ixians, sysf,
# Nearest to two: one, three, five, zero, four, seven, radios, total,
# Nearest to that: hierarchy, be, damages, answering, instalments, alimentary, counterpart, instantaneous,
# Nearest to known: blasting, empiricists, rhenish, pronunciations, trivium, materials, sabina, limitless,
# Nearest to used: radars, reappear, browsing, could, fiber, essentially, complexity, sichuan,
# Nearest to are: subsistence, culinary, outdated, endothermic, conserving, iir, nominative, precautions,
# Nearest to if: determinant, peugeot, whence, geste, dimer, notion, topology, stall,
# Nearest to i: hinted, son, shoulders, officiel, complutense, inversion, lpg, everest,
# Nearest to assembly: gorbachev, legislative, councils, judicial, perrin, criminal, zoramites, indentured,
# Nearest to accepted: apportionment, ourselves, kilgore, thucydides, westernization, undisclosed, saffron, fide,
# Nearest to notes: medieval, santander, redfield, tootsie, chuck, full, reviews, specialisation,
# Nearest to bbc: ranks, galveston, moshoeshoe, announces, listen, rer, lastnode, unconquered,
# Nearest to hold: ossification, plucking, volleys, phoneme, carrying, koyaanisqatsi, typographical, supplant,
# Nearest to frac: sum, mathbf, cdot, vectors, constant, weight, epithet, intersect,
# Nearest to pope: rieure, harar, augusta, cora, israel, horkheimer, schwerin, anastasia,
# Nearest to ocean: relay, intelsat, southern, flat, pacific, cape, adjacent, temperate,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3087 0.0314 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.3139 0.0304 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3239 0.0140 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2633 0.0305 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2268 0.0305 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2370 0.0305 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2651 0.0304 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2190 0.0304 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2260 0.0304 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.2094 0.0303 sec/batch
# Nearest to will: susceptibility, disapproving, counterintelligence, encircles, anecdotes, ixians, marchand, sysf,
# Nearest to two: five, one, three, zero, four, seven, total, radios,
# Nearest to that: hierarchy, damages, be, alimentary, answering, instalments, counterpart, civil,
# Nearest to known: blasting, rhenish, empiricists, materials, pronunciations, hesser, orbital, trivium,
# Nearest to used: radars, could, browsing, fiber, reappear, amylase, b, sichuan,
# Nearest to are: subsistence, culinary, endothermic, conserving, outdated, occur, iir, also,
# Nearest to if: determinant, whence, peugeot, geste, notion, topology, stall, forty,
# Nearest to i: hinted, son, complutense, shoulders, officiel, me, hopkinson, lpg,
# Nearest to assembly: gorbachev, legislative, judicial, councils, perrin, zoramites, maize, criminal,
# Nearest to accepted: apportionment, kilgore, ourselves, andrewes, purely, fide, saffron, decentralisation,
# Nearest to notes: medieval, santander, isbns, tootsie, redfield, chuck, full, brittle,
# Nearest to bbc: galveston, ranks, moshoeshoe, rer, announces, listen, markus, hirata,
# Nearest to hold: ossification, plucking, carrying, volleys, phoneme, koyaanisqatsi, frederik, redeemed,
# Nearest to frac: sum, mathbf, cdot, vectors, operator, left, intersect, divisor,
# Nearest to pope: harar, augusta, rieure, horkheimer, viii, pontifex, cora, israel,
# Nearest to ocean: relay, intelsat, farthest, flat, cape, pacific, bay, temperate,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2514 0.0314 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2022 0.0304 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2617 0.0303 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1376 0.0304 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.2016 0.0303 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.2315 0.0302 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1969 0.0300 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1875 0.0302 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.1899 0.0302 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1920 0.0300 sec/batch
# Nearest to will: susceptibility, anecdotes, disapproving, counterintelligence, sysf, marchand, difficult, pipe,
# Nearest to two: five, three, one, zero, four, seven, total, radios,
# Nearest to that: be, hierarchy, damages, alimentary, instalments, civil, counterpart, answering,
# Nearest to known: blasting, materials, rhenish, pronunciations, empiricists, trivium, jacobites, hesser,
# Nearest to used: radars, b, browsing, reappear, could, hy, fiber, compass,
# Nearest to are: subsistence, endothermic, culinary, conserving, lactam, wires, aspartate, iir,
# Nearest to if: determinant, whence, peugeot, geste, stall, topology, forty, dimer,
# Nearest to i: hinted, son, shoulders, complutense, ary, lpg, officiel, inversion,
# Nearest to assembly: legislative, gorbachev, judicial, councils, perrin, zoramites, cronin, maize,
# Nearest to accepted: fide, andrewes, apportionment, purely, kilgore, ourselves, animist, decentralisation,
# Nearest to notes: medieval, santander, music, isbns, tootsie, full, centum, initio,
# Nearest to bbc: ranks, galveston, moshoeshoe, rer, listen, hirata, announces, rainstorm,
# Nearest to hold: ossification, plucking, volleys, carrying, phoneme, koyaanisqatsi, redeemed, supplant,
# Nearest to frac: sum, left, cdot, mathbf, vectors, constant, operator, intersect,
# Nearest to pope: harar, augusta, pontifex, anastasius, horkheimer, rieure, viii, cora,
# Nearest to ocean: relay, intelsat, flat, cape, farthest, palaestina, pacific, adjacent,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1642 0.0313 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2150 0.0303 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1887 0.0302 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1556 0.0302 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1962 0.0302 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.2410 0.0304 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.2311 0.0303 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1731 0.0302 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1672 0.0305 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1694 0.0302 sec/batch
# Nearest to will: susceptibility, counterintelligence, anecdotes, disapproving, sysf, ixians, quietly, badougi,
# Nearest to two: five, zero, one, three, four, seven, total, expectancy,
# Nearest to that: hierarchy, be, alimentary, dianic, answering, civil, damages, flea,
# Nearest to known: blasting, materials, pronunciations, empiricists, rhenish, sabina, trivium, hesser,
# Nearest to used: radars, b, circumflex, compass, reappear, hy, tablature, essentially,
# Nearest to are: subsistence, culinary, endothermic, lactam, wires, atonal, intelligibility, conserving,
# Nearest to if: determinant, whence, geste, peugeot, topology, obtain, forty, notion,
# Nearest to i: hinted, son, me, shoulders, complutense, officiel, hopkinson, lpg,
# Nearest to assembly: legislative, gorbachev, councils, judicial, bicameral, maize, merger, zoramites,
# Nearest to accepted: apportionment, andrewes, fide, kilgore, decentralisation, purely, instrumentals, animist,
# Nearest to notes: medieval, santander, isbns, music, full, centum, tootsie, chuck,
# Nearest to bbc: ranks, galveston, moshoeshoe, announces, listen, rer, march, rosh,
# Nearest to hold: ossification, volleys, plucking, carrying, phoneme, koyaanisqatsi, surpassed, supplant,
# Nearest to frac: sum, mathbf, cdot, left, vectors, right, divisor, constant,
# Nearest to pope: harar, pontifex, augusta, horkheimer, viii, anastasius, rieure, alexandrian,
# Nearest to ocean: relay, intelsat, cape, farthest, pacific, shortwave, palaestina, atlantic,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.2305 0.0312 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1724 0.0305 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1888 0.0304 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1955 0.0305 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1274 0.0302 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1691 0.0303 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1754 0.0302 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1371 0.0304 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1819 0.0304 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2062 0.0302 sec/batch
# Nearest to will: counterintelligence, disapproving, susceptibility, anecdotes, sysf, quietly, ixians, yeoh,
# Nearest to two: five, one, three, zero, four, seven, total, six,
# Nearest to that: dianic, be, civil, instalments, hierarchy, answering, coining, damages,
# Nearest to known: jacobites, empiricists, trivium, sabina, blasting, mary, rhenish, ruler,
# Nearest to used: radars, circumflex, reappear, browsing, hy, cauldron, compass, essentially,
# Nearest to are: subsistence, culinary, endothermic, intelligibility, atonal, cookie, nominative, lactam,
# Nearest to if: determinant, whence, peugeot, geste, topology, forty, obtain, stall,
# Nearest to i: hinted, me, complutense, hopkinson, son, officiel, shoulders, your,
# Nearest to assembly: legislative, gorbachev, councils, maize, adapters, judicial, bicameral, perrin,
# Nearest to accepted: fide, kilgore, andrewes, apportionment, westernization, decentralisation, animist, slavoj,
# Nearest to notes: santander, medieval, isbns, music, full, tootsie, chuck, redfield,
# Nearest to bbc: galveston, ranks, march, moshoeshoe, announces, rer, listen, links,
# Nearest to hold: ossification, plucking, volleys, carrying, koyaanisqatsi, redeemed, encouragement, surpassed,
# Nearest to frac: sum, mathbf, cdot, left, vectors, epithet, right, divisor,
# Nearest to pope: harar, pontifex, horkheimer, gregory, augusta, rieure, viii, anastasius,
# Nearest to ocean: relay, intelsat, cape, palaestina, farthest, pacific, shortwave, flat,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2272 0.0312 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1726 0.0304 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1258 0.0302 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1573 0.0303 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0343 0.0304 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1445 0.0305 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1341 0.0302 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1464 0.0301 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1731 0.0056 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1571 0.0305 sec/batch
# Nearest to will: counterintelligence, susceptibility, disapproving, anecdotes, quietly, badougi, difficult, ixians,
# Nearest to two: five, one, zero, three, four, seven, total, estimate,
# Nearest to that: dianic, instalments, be, coining, damages, alimentary, civil, answering,
# Nearest to known: materials, empiricists, jacobites, blasting, sabina, trivium, ruler, niceties,
# Nearest to used: radars, circumflex, b, hy, tablature, browsing, reappear, compass,
# Nearest to are: culinary, subsistence, also, endothermic, conserving, lactam, atonal, living,
# Nearest to if: determinant, peugeot, geste, whence, stall, obtain, topology, leg,
# Nearest to i: hinted, me, complutense, hopkinson, officiel, son, your, milosevic,
# Nearest to assembly: legislative, gorbachev, councils, bicameral, judicial, appoints, merger, perrin,
# Nearest to accepted: andrewes, fide, decentralisation, apportionment, westernization, kilgore, animist, implicates,
# Nearest to notes: santander, music, medieval, isbns, full, rhythmic, tootsie, chuck,
# Nearest to bbc: galveston, ranks, march, links, rer, announces, rosh, moshoeshoe,
# Nearest to hold: ossification, plucking, volleys, carrying, koyaanisqatsi, surpassed, redeemed, hang,
# Nearest to frac: sum, cdot, mathbf, left, vectors, epithet, right, divisor,
# Nearest to pope: harar, pontifex, horkheimer, gregory, anastasius, viii, rieure, augusta,
# Nearest to ocean: relay, intelsat, shortwave, farthest, cape, palaestina, pacific, atlantic,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.1061 0.0314 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0897 0.0305 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.1374 0.0302 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0402 0.0302 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.1106 0.0302 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0755 0.0309 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.1143 0.0310 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.1004 0.0309 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1193 0.0304 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0263 0.0302 sec/batch
# Nearest to will: counterintelligence, anecdotes, disapproving, sysf, susceptibility, quietly, difficult, badougi,
# Nearest to two: five, three, one, zero, four, seven, total, estimate,
# Nearest to that: dianic, be, damages, david, compatibility, civil, ouster, coining,
# Nearest to known: materials, empiricists, sabina, blasting, scratched, pronunciations, hesser, jacobites,
# Nearest to used: b, radars, hy, circumflex, browsing, compass, amylase, tablature,
# Nearest to are: culinary, subsistence, although, living, conserving, also, endothermic, atonal,
# Nearest to if: determinant, peugeot, whence, topology, geste, obtain, any, quaternions,
# Nearest to i: hinted, me, complutense, hopkinson, son, justly, your, officiel,
# Nearest to assembly: legislative, councils, gorbachev, adapters, merger, bicameral, cronin, sharashka,
# Nearest to accepted: andrewes, fide, decentralisation, apportionment, kilgore, westernization, saffron, instrumentals,
# Nearest to notes: santander, medieval, music, isbns, rhythmic, full, harpersanfrancisco, tootsie,
# Nearest to bbc: march, galveston, links, ranks, rer, listen, broadcasting, markus,
# Nearest to hold: ossification, plucking, carrying, volleys, koyaanisqatsi, encouragement, redeemed, surpassed,
# Nearest to frac: sum, cdot, left, mathbf, theta, right, vectors, divisor,
# Nearest to pope: harar, anastasius, pontifex, horkheimer, viii, gregory, alexandrian, schwerin,
# Nearest to ocean: intelsat, relay, shortwave, atlantic, palaestina, farthest, atoll, pacific,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0304 0.0311 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0177 0.0302 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0267 0.0302 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0762 0.0302 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0739 0.0302 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0911 0.0301 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0732 0.0303 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.1296 0.0303 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0833 0.0304 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0637 0.0305 sec/batch
# Nearest to will: counterintelligence, anecdotes, disapproving, difficult, sysf, susceptibility, quietly, yeoh,
# Nearest to two: five, zero, one, three, four, seven, total, six,
# Nearest to that: be, compatibility, david, dianic, damages, answering, instalments, coining,
# Nearest to known: materials, sabina, empiricists, scratched, hesser, blasting, pronunciations, jacobites,
# Nearest to used: b, circumflex, as, alphabets, hy, compass, radars, tablature,
# Nearest to are: living, atonal, culinary, also, subsistence, depending, aspartate, endothermic,
# Nearest to if: determinant, whence, geste, topology, peugeot, quaternions, any, obtain,
# Nearest to i: me, hinted, tautologies, hopkinson, son, complutense, expository, droplets,
# Nearest to assembly: legislative, councils, gorbachev, adapters, approves, bicameral, merger, appoints,
# Nearest to accepted: andrewes, fide, decentralisation, apportionment, kilgore, westernization, implicates, austerlitz,
# Nearest to notes: santander, medieval, music, isbns, tootsie, rhythmic, brittle, aire,
# Nearest to bbc: march, links, galveston, ranks, rer, markus, listen, footnotes,
# Nearest to hold: ossification, plucking, carrying, volleys, surpassed, koyaanisqatsi, redeemed, encouragement,
# Nearest to frac: sum, left, right, cdot, mathbf, theta, vectors, epithet,
# Nearest to pope: harar, pontifex, anastasius, viii, horkheimer, gregory, alexandrian, phaenomena,
# Nearest to ocean: relay, intelsat, shortwave, atoll, farthest, atlantic, palaestina, radiotelephone,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0600 0.0317 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.1254 0.0305 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0626 0.0304 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0991 0.0303 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0699 0.0302 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0516 0.0302 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0845 0.0302 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0658 0.0303 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.1088 0.0303 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0911 0.0302 sec/batch
# Nearest to will: counterintelligence, disapproving, sysf, quietly, anecdotes, yeoh, capt, susceptibility,
# Nearest to two: five, zero, three, one, four, seven, total, six,
# Nearest to that: compatibility, be, dianic, instalments, david, answering, coining, civil,
# Nearest to known: sabina, materials, hesser, scratched, ruler, empiricists, assyria, jacobites,
# Nearest to used: b, circumflex, hy, alphabets, as, reappear, compass, cauldron,
# Nearest to are: living, intelligibility, culinary, atonal, conserving, subsistence, consists, depending,
# Nearest to if: determinant, whence, geste, topology, any, obtain, peugeot, forty,
# Nearest to i: me, hinted, hopkinson, complutense, son, your, droplets, justly,
# Nearest to assembly: legislative, councils, gorbachev, adapters, bicameral, approves, merger, appoints,
# Nearest to accepted: andrewes, fide, decentralisation, westernization, apportionment, kilgore, austerlitz, implicates,
# Nearest to notes: santander, medieval, music, isbns, aire, centum, brittle, harpersanfrancisco,
# Nearest to bbc: march, listen, links, galveston, rosh, footnotes, broadcasting, rer,
# Nearest to hold: ossification, plucking, volleys, carrying, surpassed, redeemed, koyaanisqatsi, hang,
# Nearest to frac: sum, left, cdot, mathbf, right, theta, weight, mascheroni,
# Nearest to pope: harar, pontifex, anastasius, viii, gregory, horkheimer, schism, hashemite,
# Nearest to ocean: relay, intelsat, shortwave, atlantic, radiotelephone, optic, microwave, farthest,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0900 0.0314 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 3.9982 0.0302 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0600 0.0301 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0547 0.0305 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0782 0.0304 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1444 0.0304 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1389 0.0301 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0590 0.0304 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0407 0.0302 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0861 0.0302 sec/batch
# Nearest to will: counterintelligence, disapproving, susceptibility, sysf, anecdotes, quietly, ixians, yeoh,
# Nearest to two: five, one, three, zero, four, seven, six, total,
# Nearest to that: compatibility, be, instalments, david, answering, dianic, damages, it,
# Nearest to known: sabina, empiricists, hesser, materials, jacobites, ruler, trivium, scratched,
# Nearest to used: b, circumflex, hy, alphabets, reappear, browsing, as, gss,
# Nearest to are: living, conserving, culinary, consists, subsistence, atonal, wires, cookie,
# Nearest to if: determinant, whence, peugeot, geste, topology, obtain, any, underpants,
# Nearest to i: me, hopkinson, hinted, complutense, your, milosevic, droplets, expository,
# Nearest to assembly: legislative, councils, adapters, gorbachev, maize, approves, settlers, merger,
# Nearest to accepted: fide, decentralisation, andrewes, westernization, apportionment, kilgore, austerlitz, implicates,
# Nearest to notes: santander, medieval, music, isbns, aire, harpersanfrancisco, full, zimmer,
# Nearest to bbc: march, listing, links, galveston, rosh, announces, listen, day,
# Nearest to hold: ossification, plucking, volleys, redeemed, carrying, surpassed, koyaanisqatsi, hang,
# Nearest to frac: sum, left, cdot, mathbf, right, epithet, mascheroni, weight,
# Nearest to pope: harar, pontifex, anastasius, viii, gregory, horkheimer, romanoff, constance,
# Nearest to ocean: relay, intelsat, shortwave, farthest, atlantic, radiotelephone, palaestina, atoll,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9976 0.0315 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0067 0.0304 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0563 0.0305 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0300 0.0303 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0819 0.0302 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0642 0.0273 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0162 0.0302 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9983 0.0304 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0318 0.0302 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9842 0.0302 sec/batch
# Nearest to will: counterintelligence, disapproving, susceptibility, quietly, sysf, flowcharts, yeoh, ixians,
# Nearest to two: five, one, three, zero, four, seven, six, total,
# Nearest to that: compatibility, be, instalments, answering, damages, dianic, alimentary, david,
# Nearest to known: also, materials, scratched, sabina, empiricists, herodotus, hesser, originated,
# Nearest to used: b, circumflex, alphabets, hy, gss, as, deflagration, germinate,
# Nearest to are: living, conserving, surrounding, atonal, culinary, subsistence, also, aspartate,
# Nearest to if: determinant, whence, peugeot, geste, underpants, topology, any, elevator,
# Nearest to i: me, hopkinson, hinted, complutense, droplets, your, milosevic, son,
# Nearest to assembly: councils, legislative, adapters, randomized, gorbachev, settlers, maize, axle,
# Nearest to accepted: andrewes, decentralisation, fide, apportionment, westernization, implicates, schweitzer, kilgore,
# Nearest to notes: santander, medieval, music, isbns, pitch, saxophone, full, aire,
# Nearest to bbc: march, links, listing, day, rosh, footnotes, galveston, rer,
# Nearest to hold: ossification, plucking, redeemed, volleys, koyaanisqatsi, carrying, surpassed, congregational,
# Nearest to frac: sum, left, cdot, mathbf, right, theta, mascheroni, epithet,
# Nearest to pope: harar, anastasius, pontifex, viii, gregory, constance, romanoff, horkheimer,
# Nearest to ocean: relay, intelsat, shortwave, atlantic, farthest, palaestina, atoll, radiotelephone,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 4.0204 0.0315 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9555 0.0302 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0395 0.0301 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0368 0.0302 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0265 0.0303 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 3.9985 0.0302 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9450 0.0302 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9526 0.0304 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9544 0.0302 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9856 0.0301 sec/batch
# Nearest to will: counterintelligence, disapproving, quietly, sysf, flowcharts, kippur, emrys, give,
# Nearest to two: one, five, three, zero, four, seven, six, total,
# Nearest to that: compatibility, be, instalments, it, damages, david, dianic, spectroscopically,
# Nearest to known: also, scratched, sabina, materials, jacobites, originated, empiricists, hesser,
# Nearest to used: b, alphabets, hy, circumflex, as, khmer, deflagration, compass,
# Nearest to are: living, conserving, although, depending, also, atonal, endothermic, culinary,
# Nearest to if: determinant, whence, any, geste, peugeot, topology, underpants, elevator,
# Nearest to i: me, droplets, hopkinson, hinted, complutense, your, my, tell,
# Nearest to assembly: councils, legislative, adapters, randomized, maize, bicameral, gorbachev, approves,
# Nearest to accepted: andrewes, decentralisation, fide, distance, correction, implicates, apportionment, fraktion,
# Nearest to notes: santander, medieval, music, isbns, saxophone, aire, full, petits,
# Nearest to bbc: march, links, listing, broadcasting, footnotes, rosh, galveston, listen,
# Nearest to hold: ossification, plucking, redeemed, volleys, hang, koyaanisqatsi, carrying, fujita,
# Nearest to frac: sum, left, cdot, right, mathbf, mascheroni, theta, epithet,
# Nearest to pope: harar, anastasius, pontifex, viii, gregory, constance, romanoff, horkheimer,
# Nearest to ocean: relay, intelsat, shortwave, atlantic, atoll, radiotelephone, palaestina, farthest,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 4.0093 0.0312 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 4.0270 0.0305 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9889 0.0303 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0347 0.0301 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0546 0.0305 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9843 0.0305 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 4.0204 0.0304 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 4.0031 0.0304 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9940 0.0311 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 4.0181 0.0305 sec/batch
# Nearest to will: counterintelligence, flowcharts, quietly, disapproving, give, those, anecdotes, sysf,
# Nearest to two: one, five, three, zero, four, seven, six, nine,
# Nearest to that: compatibility, be, instalments, it, answering, david, damages, dianic,
# Nearest to known: also, sabina, scratched, jacobites, materials, ragtime, originally, hesser,
# Nearest to used: b, circumflex, alphabets, as, hy, devised, tablature, compass,
# Nearest to are: living, atonal, depending, although, also, surrounding, consists, referred,
# Nearest to if: determinant, any, geste, whence, obtain, elevator, underpants, peugeot,
# Nearest to i: me, hopkinson, droplets, my, hinted, your, complutense, you,
# Nearest to assembly: legislative, councils, adapters, randomized, maize, gorbachev, bicameral, approves,
# Nearest to accepted: andrewes, decentralisation, fide, distance, apportionment, schweitzer, implicates, fraktion,
# Nearest to notes: santander, medieval, music, isbns, brittle, zimmer, ethnomusicology, full,
# Nearest to bbc: march, links, listing, rosh, day, footnotes, broadcasting, galveston,
# Nearest to hold: ossification, plucking, redeemed, volleys, hang, encouragement, koyaanisqatsi, fujita,
# Nearest to frac: sum, left, cdot, right, mathbf, mascheroni, theta, weight,
# Nearest to pope: harar, anastasius, viii, pontifex, gregory, constance, romanoff, schism,
# Nearest to ocean: relay, intelsat, shortwave, atoll, radiotelephone, atlantic, arabsat, palaestina,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 4.0017 0.0313 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 4.0048 0.0306 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9834 0.0303 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 4.0174 0.0303 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0478 0.0302 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 4.0180 0.0303 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 4.0098 0.0301 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9810 0.0302 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9629 0.0303 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0178 0.0304 sec/batch
# Nearest to will: quietly, give, flowcharts, kippur, those, counterintelligence, disapproving, sysf,
# Nearest to two: one, five, three, zero, four, seven, six, eight,
# Nearest to that: be, compatibility, instalments, it, dianic, couched, damages, not,
# Nearest to known: also, sabina, scratched, jacobites, materials, ruler, asahel, originally,
# Nearest to used: b, circumflex, alphabets, hy, as, euphemism, khmer, devised,
# Nearest to are: living, not, although, consists, atonal, referred, serves, depending,
# Nearest to if: determinant, whence, any, geste, peugeot, obtain, avoid, topology,
# Nearest to i: me, droplets, hopkinson, my, your, complutense, hinted, myself,
# Nearest to assembly: legislative, councils, adapters, randomized, approves, maize, bicameral, gorbachev,
# Nearest to accepted: andrewes, decentralisation, fide, distance, implicates, apportionment, schweitzer, westernization,
# Nearest to notes: medieval, santander, isbns, ethnomusicology, zimmer, music, aire, saxophone,
# Nearest to bbc: march, listing, links, footnotes, rosh, day, listen, diena,
# ...
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.9561 0.0301 sec/batch
# Nearest to will: those, kippur, takes, emrys, occurs, flowcharts, might, loses,
# Nearest to two: one, three, five, four, zero, seven, six, nine,
# Nearest to that: not, as, it, only, and, be, a, been,
# Nearest to known: also, first, originally, a, as, among, in, even,
# Nearest to used: as, b, euphemism, use, uses, alphabets, known, also,
# Nearest to are: have, and, there, although, all, is, living, or,
# Nearest to if: any, avoid, homeomorphic, underpants, there, determinant, subkeys, whence,
# Nearest to i: my, me, droplets, myself, am, you, your, stuff,
# Nearest to assembly: legislative, randomized, councils, adapters, ecclesia, approves, axle, segmented,
# Nearest to accepted: andrewes, decentralisation, schweitzer, kilgore, apportionment, implicates, fraktion, invalid,
# Nearest to notes: medieval, ethnomusicology, bonhomme, harpersanfrancisco, pitch, zimmer, stylistically, petits,
# Nearest to bbc: links, march, day, diena, listing, troughs, ionizing, december,
# Nearest to hold: fujita, ossification, cowboy, redeemed, birdman, hang, nabi, targeted,
# Nearest to frac: right, left, cdot, mascheroni, mathbf, sterility, sum, epithet,
# Nearest to pope: constance, harar, gregory, pontifex, romanoff, anastasius, dioscorus, viii,
# Nearest to ocean: relay, intelsat, atlantic, pacific, shortwave, radiotelephone, arabsat, flagship,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8552 0.0311 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8473 0.0304 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8912 0.0301 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8907 0.0304 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8835 0.0301 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8836 0.0303 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8917 0.0303 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8693 0.0302 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8813 0.0304 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8705 0.0303 sec/batch
# Nearest to will: those, kippur, otmar, takes, emrys, flowcharts, occurs, header,
# Nearest to two: one, five, three, four, zero, seven, six, eight,
# Nearest to that: not, it, be, only, been, a, as, however,
# Nearest to known: also, first, originally, as, a, fusible, among, in,
# Nearest to used: b, euphemism, as, uses, use, alphabets, devised, known,
# Nearest to are: have, and, of, is, there, or, all, not,
# Nearest to if: any, avoid, there, refuse, whence, separated, homeomorphic, underpants,
# Nearest to i: my, me, myself, am, droplets, you, your, stuff,
# Nearest to assembly: legislative, randomized, councils, adapters, unicameral, approves, segmented, bicameral,
# Nearest to accepted: andrewes, decentralisation, schweitzer, kilgore, invalid, apportionment, westernization, fide,
# Nearest to notes: medieval, ethnomusicology, zimmer, bonhomme, harpersanfrancisco, downloadable, pitch, petits,
# Nearest to bbc: links, march, diena, day, listing, troughs, footnotes, ionizing,
# Nearest to hold: fujita, ossification, cowboy, redeemed, nabi, birdman, targeted, elucidation,
# Nearest to frac: right, cdot, left, mascheroni, mathbf, sterility, epithet, mites,
# Nearest to pope: constance, harar, gregory, bologna, viii, romanoff, anastasius, pontifex,
# Nearest to ocean: relay, intelsat, atlantic, pacific, shortwave, radiotelephone, tropospheric, arabsat,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.9186 0.0314 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8673 0.0303 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8635 0.0301 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8774 0.0303 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.8923 0.0303 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8522 0.0306 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9882 0.0304 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.9266 0.0302 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.9088 0.0304 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8522 0.0300 sec/batch
# Nearest to will: those, kippur, otmar, takes, header, begin, excitations, stub,
# Nearest to two: one, five, three, four, zero, seven, six, eight,
# Nearest to that: not, it, be, only, a, as, been, the,
# Nearest to known: also, as, originally, first, a, among, in, few,
# Nearest to used: as, use, euphemism, uses, b, alphabets, are, commonly,
# Nearest to are: have, and, is, these, of, there, all, or,
# Nearest to if: any, avoid, there, homeomorphic, whence, refuse, underpants, broker,
# Nearest to i: my, me, myself, am, droplets, you, your, hopkinson,
# Nearest to assembly: legislative, randomized, approves, unicameral, adapters, councils, segmented, maize,
# Nearest to accepted: decentralisation, andrewes, kilgore, schweitzer, westernization, fide, fraktion, apportionment,
# Nearest to notes: medieval, ethnomusicology, bonhomme, zimmer, harpersanfrancisco, downloadable, petits, fulvia,
# Nearest to bbc: links, march, day, diena, listing, troughs, feast, anniversaries,
# Nearest to hold: fujita, ossification, cowboy, nabi, targeted, hang, elucidation, holds,
# Nearest to frac: right, left, mascheroni, cdot, sterility, mites, epithet, mathbf,
# Nearest to pope: constance, harar, gregory, bologna, romanoff, pontifex, anastasius, props,
# Nearest to ocean: relay, intelsat, atlantic, radiotelephone, tropospheric, pacific, arabsat, shortwave,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.8376 0.0310 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.9090 0.0302 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7729 0.0302 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8855 0.0302 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8529 0.0302 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8771 0.0302 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.9251 0.0152 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8679 0.0300 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8527 0.0302 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8481 0.0304 sec/batch
# Nearest to will: otmar, emrys, kippur, those, takes, excitations, capt, vernal,
# Nearest to two: five, one, three, four, zero, seven, six, eight,
# Nearest to that: not, be, as, it, been, a, however, only,
# Nearest to known: also, as, originally, a, first, in, many, among,
# Nearest to used: as, use, euphemism, uses, also, b, alphabets, commonly,
# Nearest to are: have, and, there, is, also, of, although, all,
# Nearest to if: any, avoid, broker, refuse, there, underpants, whence, you,
# Nearest to i: my, myself, me, am, droplets, you, your, stuff,
# Nearest to assembly: randomized, legislative, adapters, segmented, councils, unicameral, approves, ecclesia,
# Nearest to accepted: andrewes, decentralisation, schweitzer, implicates, kilgore, apportionment, fide, fraktion,
# Nearest to notes: medieval, ethnomusicology, bonhomme, downloadable, zimmer, pitch, harpersanfrancisco, petits,
# Nearest to bbc: links, day, march, diena, listing, troughs, feast, observances,
# Nearest to hold: fujita, cowboy, ossification, nabi, targeted, birdman, hang, redeemed,
# Nearest to frac: right, mascheroni, left, sterility, cdot, epithet, mites, weight,
# Nearest to pope: constance, harar, bologna, gregory, romanoff, pontifex, anastasius, dioscorus,
# Nearest to ocean: relay, intelsat, atlantic, pacific, tropospheric, radiotelephone, arabsat, shortwave,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8553 0.0312 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8378 0.0303 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8471 0.0304 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.8169 0.0301 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8850 0.0301 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8602 0.0300 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8703 0.0303 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7973 0.0303 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8305 0.0300 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.8316 0.0302 sec/batch
# Nearest to will: those, emrys, kippur, takes, might, be, same, header,
# Nearest to two: five, three, one, four, zero, seven, six, eight,
# Nearest to that: not, be, a, it, only, the, as, is,
# Nearest to known: also, as, a, originally, in, first, the, among,
# Nearest to used: as, uses, use, euphemism, b, also, known, commonly,
# Nearest to are: have, and, there, is, of, all, not, or,
# Nearest to if: any, can, avoid, not, homeomorphic, subkeys, there, you,
# Nearest to i: my, myself, me, am, droplets, you, stuff, your,
# Nearest to assembly: legislative, randomized, adapters, unicameral, councils, segmented, bicameral, approves,
# Nearest to accepted: andrewes, decentralisation, schweitzer, implicates, kilgore, fide, unanimously, apportionment,
# Nearest to notes: medieval, ethnomusicology, bonhomme, downloadable, harpersanfrancisco, zimmer, petits, santander,
# Nearest to bbc: links, march, diena, day, listing, troughs, programmes, ionizing,
# Nearest to hold: fujita, cowboy, ossification, hang, targeted, adult, nabi, holds,
# Nearest to frac: right, left, mascheroni, cdot, sterility, mites, epithet, mathbf,
# Nearest to pope: constance, harar, gregory, bologna, pontifex, romanoff, anastasius, dioscorus,
# Nearest to ocean: intelsat, relay, atlantic, pacific, radiotelephone, shortwave, tropospheric, intersputnik,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7845 0.0311 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8231 0.0302 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8771 0.0304 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8766 0.0303 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8579 0.0301 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.9089 0.0302 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8625 0.0304 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8389 0.0301 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8617 0.0303 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8618 0.0305 sec/batch
# Nearest to will: takes, those, emrys, kippur, header, occurs, otmar, stub,
# Nearest to two: one, three, five, four, zero, seven, six, eight,
# Nearest to that: not, a, be, have, as, only, the, for,
# Nearest to known: also, as, a, first, originally, in, among, even,
# Nearest to used: as, uses, use, euphemism, b, often, in, alphabets,
# Nearest to are: have, there, and, all, these, or, although, of,
# Nearest to if: any, avoid, there, homeomorphic, can, separated, determinant, will,
# Nearest to i: my, me, myself, am, droplets, you, sinc, stuff,
# Nearest to assembly: legislative, randomized, unicameral, adapters, approves, councils, ecclesia, bicameral,
# Nearest to accepted: decentralisation, andrewes, schweitzer, implicates, unanimously, fide, apportionment, fraktion,
# Nearest to notes: medieval, ethnomusicology, bonhomme, downloadable, harpersanfrancisco, sidecar, zimmer, pitch,
# Nearest to bbc: links, diena, march, day, listing, troughs, december, programmes,
# Nearest to hold: fujita, cowboy, ossification, hang, redeemed, holds, targeted, adult,
# Nearest to frac: right, left, cdot, mascheroni, sterility, mites, mathbf, sum,
# Nearest to pope: constance, harar, gregory, pontifex, bologna, romanoff, anastasius, dioscorus,
# Nearest to ocean: relay, intelsat, atlantic, pacific, tropospheric, radiotelephone, shortwave, intersputnik,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8718 0.0313 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8412 0.0302 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8556 0.0304 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8612 0.0304 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8910 0.0302 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8616 0.0303 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8449 0.0303 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8621 0.0302 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8309 0.0303 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8302 0.0302 sec/batch
# Nearest to will: those, emrys, takes, all, kippur, be, does, otmar,
# Nearest to two: three, one, five, four, zero, seven, six, eight,
# Nearest to that: not, be, a, only, the, have, of, as,
# Nearest to known: also, as, in, a, first, originally, among, the,
# Nearest to used: as, uses, use, in, euphemism, b, are, often,
# Nearest to are: have, and, all, there, is, of, for, not,
# Nearest to if: any, avoid, there, homeomorphic, can, subkeys, separated, decided,
# Nearest to i: my, me, am, myself, droplets, you, hopkinson, your,
# Nearest to assembly: legislative, randomized, approves, unicameral, adapters, councils, ecclesia, segmented,
# Nearest to accepted: decentralisation, andrewes, schweitzer, unanimously, implicates, fraktion, kilgore, apportionment,
# Nearest to notes: medieval, ethnomusicology, bonhomme, downloadable, harpersanfrancisco, zimmer, sidecar, multisyllabic,
# Nearest to bbc: diena, links, day, march, listing, troughs, observances, ionizing,
# Nearest to hold: fujita, cowboy, ossification, targeted, redeemed, nabi, elucidation, holds,
# Nearest to frac: right, left, mascheroni, cdot, mites, sterility, shift, epithet,
# Nearest to pope: constance, harar, bologna, gregory, pontifex, dioscorus, anastasius, clearance,
# Nearest to ocean: relay, intelsat, atlantic, tropospheric, radiotelephone, pacific, shortwave, intersputnik,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8749 0.0315 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8414 0.0309 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9527 0.0310 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.9266 0.0311 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.9147 0.0307 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8815 0.0303 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7827 0.0300 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8496 0.0302 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7351 0.0302 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8728 0.0302 sec/batch
# Nearest to will: those, takes, otmar, kippur, header, emrys, all, difficult,
# Nearest to two: one, five, three, four, zero, seven, six, nine,
# Nearest to that: not, it, a, only, as, be, have, the,
# Nearest to known: also, as, originally, in, a, first, among, many,
# Nearest to used: as, use, uses, euphemism, b, in, alphabets, using,
# Nearest to are: have, there, and, all, these, of, is, or,
# Nearest to if: any, avoid, there, can, homeomorphic, subkeys, glauben, refuse,
# Nearest to i: my, me, am, myself, droplets, you, stuff, your,
# Nearest to assembly: legislative, randomized, unicameral, approves, councils, adapters, segmented, ecclesia,
# Nearest to accepted: decentralisation, andrewes, unanimously, fraktion, westernization, schweitzer, apportionment, salomon,
# Nearest to notes: ethnomusicology, medieval, bonhomme, downloadable, harpersanfrancisco, zimmer, links, rattlesnake,
# Nearest to bbc: links, diena, day, listing, march, observances, troughs, programmes,
# Nearest to hold: fujita, cowboy, targeted, holds, ossification, nabi, redeemed, elucidation,
# Nearest to frac: right, left, sterility, mascheroni, mites, cdot, precision, shift,
# Nearest to pope: constance, harar, bologna, gregory, pontifex, dioscorus, popes, romanoff,
# Nearest to ocean: relay, intelsat, atlantic, pacific, tropospheric, radiotelephone, intersputnik, shortwave,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8459 0.0313 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8304 0.0308 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# W0617 13:41:00.920187 140685572474752 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/saver.py:1276: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
